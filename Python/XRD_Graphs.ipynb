# %%
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path
import numpy as np
import statistics as stats
from datetime import datetime
import scipy.optimize as optomize

# %%
flash = pd.read_csv(Path("/Users/christiannorman/Documents/Crus Center/Scholar/FJH/data/XRD/Oct24_flash1_Graph.csv"))
pre = pd.read_csv(Path("/Users/christiannorman/Documents/Crus Center/Scholar/FJH/data/XRD/DryCarbonPowder_Graph.csv"))

# %%
#plt.plot(pre['#twotheta'], np.subtract(pre[' yobs'], pre[' bkg']))
plt.plot(flash['#twotheta'], np.subtract(flash[' yobs'], flash[' bkg']), color = '#F04723')
plt.title("Pre Flash Pattern")
plt.ylabel('Intensity (cps)')
plt.xlabel('2θ')
plt.ylim([-70, 425])
plt.show()

# %%
plt.plot(pre['#twotheta'], np.subtract(pre[' yobs'], pre[' bkg']))
#plt.plot(flash['#twotheta'], np.subtract(flash[' yobs'], flash[' bkg']), color = '#F04723')
plt.title("Pre Flash Pattern")
plt.ylabel('Intensity (cps)')
plt.xlabel('2θ')
plt.ylim([-70, 425])
plt.show()
